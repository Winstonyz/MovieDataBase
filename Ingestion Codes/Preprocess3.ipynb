# %%
import pandas

# %%
df = pandas.read_csv('./title.akas.tsv/data.tsv', sep = '\t')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
# 5  tt0000001         6                 Carmencita     US       \N
# 6  tt0000001         7                 Carmencita     \N       \N
# 7  tt0000001         8                    カルメンチータ     JP       ja
# 8  tt0000002         1     Le clown et ses chiens     \N       \N
# 9  tt0000002         2     Le clown et ses chiens     FR       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# ...

# %%
df.columns
# Out:
# Index(['titleId', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30939614, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (30939614, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30939614 entries, 0 to 30939613
# Data columns (total 8 columns):
# titleId            object
# ordering           int64
# title              object
# region             object
# language           object
# types              object
# attributes         object
# isOriginalTitle    object
# dtypes: int64(1), object(7)
# memory usage: 1.8+ GB

# %%
processed_df = df[['titleId', 'ordering', 'title', 'region']]

# %%
processed_df.head(10)
# Out:
#      titleId  ordering                      title region
# 0  tt0000001         1                 Карменсіта     UA
# 1  tt0000001         2                 Carmencita     DE
# 2  tt0000001         3  Carmencita - spanyol tánc     HU
# 3  tt0000001         4                 Καρμενσίτα     GR
# 4  tt0000001         5                 Карменсита     RU
# 5  tt0000001         6                 Carmencita     US
# 6  tt0000001         7                 Carmencita     \N
# 7  tt0000001         8                    カルメンチータ     JP
# 8  tt0000002         1     Le clown et ses chiens     \N
# 9  tt0000002         2     Le clown et ses chiens     FR

# %%
pandas.__version__
# Out:
# '0.23.4'

# %%
new_processed_df = processed_df [(processed_df.region == 'US')]

# %%
new_processed_df.head(10)
# Out:
#       titleId  ordering                                        title region
# 5   tt0000001         6                                   Carmencita     US
# 14  tt0000002         7                       The Clown and His Dogs     US
# 33  tt0000005        10                             Blacksmith Scene     US
# 36  tt0000005         1                          Blacksmithing Scene     US
# 41  tt0000005         6                          Blacksmith Scene #1     US
# 42  tt0000005         7                                Blacksmithing     US
# 47  tt0000006         3                            Chinese Opium Den     US
# 51  tt0000007         1  Corbett and Courtney Before the Kinetograph     US
# 55  tt0000007         5                   The Corbett-Courtney Fight     US
# 56  tt0000007         6               Jim Corbett vs. Peter Courtney     US

# %%
new_processed_df = new_processed_df[['titleId', 'ordering', 'title']]

# %%
new_processed_df.head(10)
# Out:
#       titleId  ordering                                        title
# 5   tt0000001         6                                   Carmencita
# 14  tt0000002         7                       The Clown and His Dogs
# 33  tt0000005        10                             Blacksmith Scene
# 36  tt0000005         1                          Blacksmithing Scene
# 41  tt0000005         6                          Blacksmith Scene #1
# 42  tt0000005         7                                Blacksmithing
# 47  tt0000006         3                            Chinese Opium Den
# 51  tt0000007         1  Corbett and Courtney Before the Kinetograph
# 55  tt0000007         5                   The Corbett-Courtney Fight
# 56  tt0000007         6               Jim Corbett vs. Peter Courtney

# %%
new_processed_df.to_csv('akas.csv', index=False)

# %%
df = pandas.read_csv('./title.basics.tsv/data.tsv', sep = '\t')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(20)
# Out:
#        tconst titleType                                 primaryTitle  \
# 0   tt0000001     short                                   Carmencita
# 1   tt0000002     short                       Le clown et ses chiens
# 2   tt0000003     short                               Pauvre Pierrot
# 3   tt0000004     short                                  Un bon bock
# 4   tt0000005     short                             Blacksmith Scene
# 5   tt0000006     short                            Chinese Opium Den
# 6   tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     short                                   Miss Jerry
# 9   tt0000010     short                          Leaving the Factory
# 10  tt0000011     short                      Akrobatisches Potpourri
# 11  tt0000012     short                       The Arrival of a Train
# 12  tt0000013     short  The Photographical Congress Arrives in Lyon
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8688756 entries, 0 to 8688755
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtypes: object(9)
# memory usage: 596.6+ MB

# %%
df_test=df[df.tconst.isin(new_processed_df.titleId)]

# %%
df_test.head(20)
# Out:
#        tconst titleType                                 primaryTitle  \
# 0   tt0000001     short                                   Carmencita
# 1   tt0000002     short                       Le clown et ses chiens
# 4   tt0000005     short                             Blacksmith Scene
# 5   tt0000006     short                            Chinese Opium Den
# 6   tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     short                                   Miss Jerry
# 9   tt0000010     short                          Leaving the Factory
# 11  tt0000012     short                       The Arrival of a Train
# 12  tt0000013     short  The Photographical Congress Arrives in Lyon
# 13  tt0000014     short                          The Waterer Watered
# 14  tt0000015     short                          Autour d'une cabine
# 15  tt0000016     short                        Boat Leaving the Port
# ...

# %%
df_test.to_csv('basics_filtered_based_US_tconst.csv', index=False)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1219644 entries, 0 to 8688711
# Data columns (total 9 columns):
# tconst            1219644 non-null object
# titleType         1219644 non-null object
# primaryTitle      1219644 non-null object
# originalTitle     1219644 non-null object
# isAdult           1219644 non-null object
# startYear         1219644 non-null object
# endYear           1219644 non-null object
# runtimeMinutes    1219644 non-null object
# genres            1219644 non-null object
# dtypes: object(9)
# memory usage: 93.1+ MB

# %%
df_test_filtered = df_test [(df_test.runtimeMinutes != '\\N') & (df_test.startYear != '\\N') ]

# %%
df_test_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764851 entries, 0 to 8688692
# Data columns (total 9 columns):
# tconst            764851 non-null object
# titleType         764851 non-null object
# primaryTitle      764851 non-null object
# originalTitle     764851 non-null object
# isAdult           764851 non-null object
# startYear         764851 non-null object
# endYear           764851 non-null object
# runtimeMinutes    764851 non-null object
# genres            764851 non-null object
# dtypes: object(9)
# memory usage: 58.4+ MB

# %%
df_test_filtered.head(10)
# Out:
#        tconst titleType                                 primaryTitle  \
# 0   tt0000001     short                                   Carmencita
# 1   tt0000002     short                       Le clown et ses chiens
# 4   tt0000005     short                             Blacksmith Scene
# 5   tt0000006     short                            Chinese Opium Den
# 6   tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     short                                   Miss Jerry
# 9   tt0000010     short                          Leaving the Factory
# 11  tt0000012     short                       The Arrival of a Train
# 12  tt0000013     short  The Photographical Congress Arrives in Lyon
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# ...

# %%
df_test_filtered['runtimeMinutes'] = df_test_filtered['runtimeMinutes'].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764851 entries, 0 to 8688692
# Data columns (total 9 columns):
# tconst            764851 non-null object
# titleType         764851 non-null object
# primaryTitle      764851 non-null object
# originalTitle     764851 non-null object
# isAdult           764851 non-null object
# startYear         764851 non-null object
# endYear           764851 non-null object
# runtimeMinutes    764851 non-null int32
# genres            764851 non-null object
# dtypes: int32(1), object(8)
# memory usage: 55.4+ MB

# %%
df_test_filtered_runtime_more_20 = df_test_filtered [(df_test_filtered.runtimeMinutes > 20)]

# %%
df_test_filtered_runtime_more_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489949 entries, 8 to 8688616
# Data columns (total 9 columns):
# tconst            489949 non-null object
# titleType         489949 non-null object
# primaryTitle      489949 non-null object
# originalTitle     489949 non-null object
# isAdult           489949 non-null object
# startYear         489949 non-null object
# endYear           489949 non-null object
# runtimeMinutes    489949 non-null int32
# genres            489949 non-null object
# dtypes: int32(1), object(8)
# memory usage: 35.5+ MB

# %%
df_akas = pandas.read_csv('./akas_region_US.csv')

# %%
df_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299544 entries, 0 to 1299543
# Data columns (total 3 columns):
# titleId     1299544 non-null object
# ordering    1299544 non-null int64
# title       1299544 non-null object
# dtypes: int64(1), object(2)
# memory usage: 29.7+ MB

# %%
df_new_akas = df_akas[df_akas.titleId.isin(df_test_filtered_runtime_more_20.tconst)]

# %%
df_new_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541142 entries, 12 to 1299537
# Data columns (total 3 columns):
# titleId     541142 non-null object
# ordering    541142 non-null int64
# title       541142 non-null object
# dtypes: int64(1), object(2)
# memory usage: 16.5+ MB

# %%
df_new_akas.to_csv('akas.csv', index=False)

# %%
df_test_filtered_runtime_more_20.to_csv('basics.csv', index=False)

# %%
df_crew = pandas.read_csv('./title.crew.tsv/data.tsv', sep = '\t')

# %%
df_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8688756 entries, 0 to 8688755
# Data columns (total 3 columns):
# tconst       object
# directors    object
# writers      object
# dtypes: object(3)
# memory usage: 198.9+ MB

# %%
df_new_crew = df_crew[df_crew.tconst.isin(df_new_akas.titleId)]

# %%
df_new_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489949 entries, 8 to 8688616
# Data columns (total 3 columns):
# tconst       489949 non-null object
# directors    489949 non-null object
# writers      489949 non-null object
# dtypes: object(3)
# memory usage: 15.0+ MB

# %%
df_new_crew.to_csv('crew.csv', index=False)

# %%
df_episode = pandas.read_csv('./title.episode.tsv/data.tsv', sep = '\t')

# %%
df_episode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6499009 entries, 0 to 6499008
# Data columns (total 4 columns):
# tconst           object
# parentTconst     object
# seasonNumber     object
# episodeNumber    object
# dtypes: object(4)
# memory usage: 198.3+ MB

# %%
df_new_episode = df_episode[df_episode.tconst.isin(df_new_akas.titleId)]

# %%
df_new_episode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121644 entries, 114 to 6498739
# Data columns (total 4 columns):
# tconst           121644 non-null object
# parentTconst     121644 non-null object
# seasonNumber     121644 non-null object
# episodeNumber    121644 non-null object
# dtypes: object(4)
# memory usage: 4.6+ MB

# %%
df_new_episode.to_csv('episode.csv', index=False)

# %%
df_principals = pandas.read_csv('./title.principals.tsv/data.tsv', sep = '\t')

# %%
df_principals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48828994 entries, 0 to 48828993
# Data columns (total 6 columns):
# tconst        object
# ordering      int64
# nconst        object
# category      object
# job           object
# characters    object
# dtypes: int64(1), object(5)
# memory usage: 2.2+ GB

# %%
df_new_principals = df_principals[df_principals.tconst.isin(df_new_akas.titleId)]

# %%
df_new_principals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4032123 entries, 24 to 48828166
# Data columns (total 6 columns):
# tconst        object
# ordering      int64
# nconst        object
# category      object
# job           object
# characters    object
# dtypes: int64(1), object(5)
# memory usage: 215.3+ MB

# %%
df_new_principals.head(30)
# Out:
#          tconst  ordering     nconst         category  \
# 24    tt0000009         1  nm0063086          actress
# 25    tt0000009         2  nm0183823            actor
# 26    tt0000009         3  nm1309758            actor
# 27    tt0000009         4  nm0085156         director
# 735   tt0000446         1  nm0567363         director
# 1040  tt0000574        10  nm0675239  cinematographer
# 1041  tt0000574         1  nm0846887          actress
# 1042  tt0000574         2  nm0846894            actor
# 1043  tt0000574         3  nm1431224            actor
# 1044  tt0000574         4  nm3002376            actor
# 1045  tt0000574         5  nm0846879         director
# 1046  tt0000574         6  nm0317210         producer
# 1047  tt0000574         7  nm0425854         producer
# 1048  tt0000574         8  nm0846911         producer
# 1049  tt0000574         9  nm2421834         composer
# 1100  tt0000591         1  nm0906197            actor
# ...

# %%
df_new_principals.to_csv('principals.csv', index=False)

# %%
df_ratings = pandas.read_csv('./title.ratings.tsv/data.tsv', sep = '\t')

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213990 entries, 0 to 1213989
# Data columns (total 3 columns):
# tconst           1213990 non-null object
# averageRating    1213990 non-null float64
# numVotes         1213990 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 27.8+ MB

# %%
df_new_ratings = df_ratings[df_ratings.tconst.isin(df_new_akas.titleId)]

# %%
df_new_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323057 entries, 8 to 1213971
# Data columns (total 3 columns):
# tconst           323057 non-null object
# averageRating    323057 non-null float64
# numVotes         323057 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.9+ MB

# %%
df_new_ratings.head(20)
# Out:
#         tconst  averageRating  numVotes
# 8    tt0000009            5.9       193
# 314  tt0000446            6.3        25
# 373  tt0000574            6.1       750
# 382  tt0000591            5.2        16
# 437  tt0000679            5.3        65
# 618  tt0000969            6.7        25
# 710  tt0001105            6.5       890
# 776  tt0001285            5.6        57
# 787  tt0001321            5.3        55
# 803  tt0001381            5.4        37
# 817  tt0001432            5.6        27
# 834  tt0001482            5.1        78
# 839  tt0001498            7.7        12
# 870  tt0001592            5.5        14
# 876  tt0001614            6.1        26
# 892  tt0001692            5.3        14
# 923  tt0001790            6.0        44
# 942  tt0001877            5.3        69
# 945  tt0001892            5.9       227
# 948  tt0001911            4.5        22

# %%
df_new_ratings.to_csv('ratings.csv', index=False)

# %%
df_name_basics = pandas.read_csv('./name.basics.tsv/data.tsv', sep = '\t')

# %%
df_name_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11407060 entries, 0 to 11407059
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# dtypes: object(6)
# memory usage: 522.2+ MB

# %%
df_new_name_basics = df_name_basics[df_name_basics.nconst.isin(df_new_principals.nconst)]

# %%
df_new_name_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1106616 entries, 0 to 11407035
# Data columns (total 6 columns):
# nconst               1106616 non-null object
# primaryName          1106616 non-null object
# birthYear            1106616 non-null object
# deathYear            1106616 non-null object
# primaryProfession    996906 non-null object
# knownForTitles       1106616 non-null object
# dtypes: object(6)
# memory usage: 59.1+ MB

# %%
df_new_name_basics.head(10)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# 8            actor,soundtrack,producer
# ...

# %%
df_new_name_basics.to_csv('name.basics.csv', index=False)
