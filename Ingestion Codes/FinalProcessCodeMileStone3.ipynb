# %%
import pandas

# %%
df_basics = pandas.read_csv('./title.basics.csv')

# %%
df_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489949 entries, 0 to 489948
# Data columns (total 9 columns):
# tconst            489949 non-null object
# titleType         489949 non-null object
# primaryTitle      489949 non-null object
# originalTitle     489949 non-null object
# isAdult           489949 non-null int64
# startYear         489949 non-null int64
# endYear           489949 non-null object
# runtimeMinutes    489949 non-null int64
# genres            489949 non-null object
# dtypes: int64(3), object(6)
# memory usage: 33.6+ MB

# %%
df_genres_of = df_basics[['tconst', 'genres']]

# %%
df_genres_of.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489949 entries, 0 to 489948
# Data columns (total 2 columns):
# tconst    489949 non-null object
# genres    489949 non-null object
# dtypes: object(2)
# memory usage: 7.5+ MB

# %%
df_genres_of = df_genres_of.drop_duplicates()

# %%
df_genres_of.to_csv('genreOf.csv', index=False)

# %%
df_basics_without_genres = df_basics[['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes']]

# %%
df_basics_without_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489949 entries, 0 to 489948
# Data columns (total 8 columns):
# tconst            489949 non-null object
# titleType         489949 non-null object
# primaryTitle      489949 non-null object
# originalTitle     489949 non-null object
# isAdult           489949 non-null int64
# startYear         489949 non-null int64
# endYear           489949 non-null object
# runtimeMinutes    489949 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 29.9+ MB

# %%
df_basics_without_genres.to_csv('movie.csv', index=False)

# %%
df_genres = df_genres_of[['genres']]

# %%
df_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489949 entries, 0 to 489948
# Data columns (total 1 columns):
# genres    489949 non-null object
# dtypes: object(1)
# memory usage: 3.7+ MB

# %%
df_genres_nodup = df_genres.drop_duplicates()

# %%
df_genres_nodup.to_csv('genres.csv', index=False)

# %%
df_genres_nodup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1841 entries, 0 to 488531
# Data columns (total 1 columns):
# genres    1841 non-null object
# dtypes: object(1)
# memory usage: 28.8+ KB

# %%
df_basics_without_genres.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     short                      Miss Jerry
# 1  tt0000446     short                      Kit Carson
# 2  tt0000574     movie     The Story of the Kelly Gang
# 3  tt0000591     movie                The Prodigal Son
# 4  tt0000679     movie  The Fairylogue and Radio-Plays
#
#                     originalTitle  isAdult  startYear endYear  runtimeMinutes
# 0                      Miss Jerry        0       1894      \N              40
# 1                      Kit Carson        0       1903      \N              21
# 2     The Story of the Kelly Gang        0       1906      \N              70
# 3               L'enfant prodigue        0       1907      \N              90
# 4  The Fairylogue and Radio-Plays        0       1908      \N             120

# %%
df_person = pandas.read_csv('./name.basics.csv')

# %%
df_person.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0053137,tt0031983,tt0050419,tt0072308
# 1  tt0037382,tt0117057,tt0071877,tt0038355
# 2  tt0056404,tt0057345,tt0054452,tt0049189
# 3  tt0072562,tt0078723,tt0080455,tt0077975
# 4  tt0069467,tt0083922,tt0060827,tt0050986

# %%
writers = df_person.loc[df_person['primaryProfession'].str.contains("writer", case=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-7b4a95fdef19> in <module>()
# ----> 1 writers = df_person.loc[df_person['primaryProfession'].str.contains("writer", case=False)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1865             self._validate_key(key, axis)
#    1866             return self._get_slice_axis(key, axis=axis)
# -> 1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
# ...

# %%
df_person_pP_not_null = df_person[df_person['primaryProfession'].notnull()]

# %%
df_person_pP_not_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 996906 entries, 0 to 1106615
# Data columns (total 6 columns):
# nconst               996906 non-null object
# primaryName          996906 non-null object
# birthYear            996906 non-null object
# deathYear            996906 non-null object
# primaryProfession    996906 non-null object
# knownForTitles       996906 non-null object
# dtypes: object(6)
# memory usage: 53.2+ MB

# %%
df_person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106616 entries, 0 to 1106615
# Data columns (total 6 columns):
# nconst               1106616 non-null object
# primaryName          1106616 non-null object
# birthYear            1106616 non-null object
# deathYear            1106616 non-null object
# primaryProfession    996906 non-null object
# knownForTitles       1106616 non-null object
# dtypes: object(6)
# memory usage: 50.7+ MB

# %%
writers = df_person_pP_not_null.loc[df_person_pP_not_null['primaryProfession'].str.contains("writer", case=False)]

# %%
writers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235204 entries, 3 to 1106611
# Data columns (total 6 columns):
# nconst               235204 non-null object
# primaryName          235204 non-null object
# birthYear            235204 non-null object
# deathYear            235204 non-null object
# primaryProfession    235204 non-null object
# knownForTitles       235204 non-null object
# dtypes: object(6)
# memory usage: 12.6+ MB

# %%
writers.head(50)
# Out:
#         nconst              primaryName birthYear deathYear  \
# 3    nm0000004             John Belushi      1949      1982
# 4    nm0000005           Ingmar Bergman      1918      2007
# 18   nm0000019         Federico Fellini      1920      1993
# 23   nm0000024             John Gielgud      1904      2000
# 26   nm0000027            Alec Guinness      1914      2000
# 30   nm0000031        Katharine Hepburn      1907      2003
# 31   nm0000032          Charlton Heston      1923      2008
# 35   nm0000036            Buster Keaton      1895      1966
# 39   nm0000040          Stanley Kubrick      1928      1999
# 40   nm0000041           Akira Kurosawa      1910      1998
# 44   nm0000045                Bruce Lee      1940      1973
# 45   nm0000046             Vivien Leigh      1913      1967
# 47   nm0000048              Peter Lorre      1904      1964
# 49   nm0000050             Groucho Marx      1890      1977
# 50   nm0000051              James Mason      1909      1984
# ...

# %%
director = df_person_pP_not_null.loc[df_person_pP_not_null['primaryProfession'].str.contains("director", case=False)]

# %%
director.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205722 entries, 4 to 1106613
# Data columns (total 6 columns):
# nconst               205722 non-null object
# primaryName          205722 non-null object
# birthYear            205722 non-null object
# deathYear            205722 non-null object
# primaryProfession    205722 non-null object
# knownForTitles       205722 non-null object
# dtypes: object(6)
# memory usage: 11.0+ MB

# %%
actor = df_person_pP_not_null.loc[df_person_pP_not_null['primaryProfession'].str.contains("actor", case=False)]

# %%
actor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346739 entries, 0 to 1106614
# Data columns (total 6 columns):
# nconst               346739 non-null object
# primaryName          346739 non-null object
# birthYear            346739 non-null object
# deathYear            346739 non-null object
# primaryProfession    346739 non-null object
# knownForTitles       346739 non-null object
# dtypes: object(6)
# memory usage: 18.5+ MB

# %%
actress = df_person_pP_not_null.loc[df_person_pP_not_null['primaryProfession'].str.contains("actor", case=False)]

# %%
actress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346739 entries, 0 to 1106614
# Data columns (total 6 columns):
# nconst               346739 non-null object
# primaryName          346739 non-null object
# birthYear            346739 non-null object
# deathYear            346739 non-null object
# primaryProfession    346739 non-null object
# knownForTitles       346739 non-null object
# dtypes: object(6)
# memory usage: 18.5+ MB

# %%
actress = actress.drop_duplicates()

# %%
actress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346739 entries, 0 to 1106614
# Data columns (total 6 columns):
# nconst               346739 non-null object
# primaryName          346739 non-null object
# birthYear            346739 non-null object
# deathYear            346739 non-null object
# primaryProfession    346739 non-null object
# knownForTitles       346739 non-null object
# dtypes: object(6)
# memory usage: 18.5+ MB

# %%
writers.to_csv('writers.csv', index=False)

# %%
actor.to_csv('actors.csv', index=False)

# %%
actress.to_csv('actresses.csv', index=False)

# %%
director.to_csv('directors.csv', index=False)

# %%
director
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director['primaryProfession'].str.split(',', 2, expand=True)
# Out:
#                           0                   1                    2
# 4                    writer            director                actor
# 7                     actor          soundtrack             director
# 9                     actor          soundtrack             director
# 18                   writer            director   assistant_director
# 23                    actor              writer             director
# 31                    actor            director               writer
# 32                 director            producer                actor
# 35                    actor              writer             director
# 36               soundtrack               actor             director
# 39                   writer            director             producer
# 40                   writer            director   assistant_director
# 55                    actor            producer             director
# 58                    actor            producer             director
# ...

# %%
director
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director = director.join(director['primaryProfession'].str.split(',', expand=True).rename(columns={0:'Job1', 1:'Job2', 2:'Job3'}))

# %%
director = director[['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession', 'knownForTitles', 'Job1', 'Job2' , 'Job3']]

# %%
director = director[['nconst', 'primaryName', 'birthYear', 'deathYear', 'knownForTitles']]

# %%
director
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director = director[director['birthYear'].notnull()]

# %%
director
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director_filtered = director [(director.birthYear != '\\N')]

# %%
director_filtered = director_filtered [(director_filtered.knownForTitles != '\\N')]

# %%
director_filtered
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director_filtered.to_csv('director_filtered_NoNULLBirthYear_NoNULLTitle.csv', index=False)

# %%
director_filtered = director_filtered.join(director_filtered['knownForTitles'].str.split(',', expand=True).rename(columns={0:'Title1', 1:'Title2', 2:'Title3', 3:'Title4'}))

# %%
director_filtered
# Out:
#             nconst                primaryName birthYear deathYear  \
# 4        nm0000005             Ingmar Bergman      1918      2007
# 7        nm0000008              Marlon Brando      1924      2004
# 9        nm0000010               James Cagney      1899      1986
# 18       nm0000019           Federico Fellini      1920      1993
# 23       nm0000024               John Gielgud      1904      2000
# 31       nm0000032            Charlton Heston      1923      2008
# 32       nm0000033           Alfred Hitchcock      1899      1980
# 35       nm0000036              Buster Keaton      1895      1966
# 36       nm0000037                 Gene Kelly      1912      1996
# 39       nm0000040            Stanley Kubrick      1928      1999
# 40       nm0000041             Akira Kurosawa      1910      1998
# 55       nm0000056                Paul Newman      1925      2008
# 58       nm0000059           Laurence Olivier      1907      1989
# ...

# %%
director_filtered = director_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1', 'Title2', 'Title3', 'Title4']]

# %%
director_filtered
# Out:
#             nconst                primaryName birthYear deathYear      Title1  \
# 4        nm0000005             Ingmar Bergman      1918      2007   tt0069467
# 7        nm0000008              Marlon Brando      1924      2004   tt0078788
# 9        nm0000010               James Cagney      1899      1986   tt0031867
# 18       nm0000019           Federico Fellini      1920      1993   tt0050783
# 23       nm0000024               John Gielgud      1904      2000   tt0071877
# 31       nm0000032            Charlton Heston      1923      2008   tt0052618
# 32       nm0000033           Alfred Hitchcock      1899      1980   tt0052357
# 35       nm0000036              Buster Keaton      1895      1966   tt0015324
# 36       nm0000037                 Gene Kelly      1912      1996   tt0041716
# 39       nm0000040            Stanley Kubrick      1928      1999   tt0120663
# 40       nm0000041             Akira Kurosawa      1910      1998   tt0089881
# ...

# %%
Title1 = director_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1']]

# %%
Title2 = director_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title2']]

# %%
Title3 = director_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title3']]

# %%
Title4 = director_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title4']]

# %%
Title1 = Title1[Title1['Title1'].notnull()]

# %%
Title2 = Title2[Title2['Title2'].notnull()]

# %%
Title3 = Title3[Title3['Title3'].notnull()]

# %%
Title4 = Title4[Title4['Title4'].notnull()]

# %%
pandas.concat([Title1, clickDF], ignore_index=True)

# %%
Title1 = Title1

# %%
Title1.rename(columns = {'Title1':'Title'}, inplace = True)

# %%
Title2.rename(columns = {'Title2':'Title'}, inplace = True)

# %%
Title3.rename(columns = {'Title3':'Title'}, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
Title4.rename(columns = {'Title4':'Title'}, inplace = True)

# %%
Title_edited = pandas.concat([Title1, Title2, Title3, Title4], ignore_index=True)

# %%
directed_by = Title_edited[['nconst', 'Title']]

# %%
directed_by
# Out:
#            nconst       Title
# 0       nm0000005   tt0069467
# 1       nm0000008   tt0078788
# 2       nm0000010   tt0031867
# 3       nm0000019   tt0050783
# 4       nm0000024   tt0071877
# 5       nm0000032   tt0052618
# 6       nm0000033   tt0052357
# 7       nm0000036   tt0015324
# 8       nm0000037   tt0041716
# 9       nm0000040   tt0120663
# 10      nm0000041   tt0089881
# 11      nm0000056   tt0084855
# 12      nm0000059   tt0077269
# 13      nm0000071   tt0052561
# 14      nm0000076   tt0075860
# 15      nm0000080   tt0038991
# 16      nm0000087   tt5847740
# 17      nm0000088   tt0063752
# 18      nm0000090   tt0139809
# 19      nm0000091   tt0152930
# 20      nm0000095   tt0075686
# 21      nm0000097   tt0426592
# 22      nm0000099   tt0108399
# 23      nm0000108   tt0119116
# 24      nm0000110   tt0116477
# 25      nm0000111   tt0086567
# 26      nm0000114   tt0105236
# 27      nm0000116   tt0090605
# 28      nm0000123   tt0465538
# 29      nm0000127   tt0111686
# ...

# %%
directed_by.to_csv('directed_by.csv', index=False)

# %%
writers
# Out:
#             nconst               primaryName birthYear deathYear  \
# 3        nm0000004              John Belushi      1949      1982
# 4        nm0000005            Ingmar Bergman      1918      2007
# 18       nm0000019          Federico Fellini      1920      1993
# 23       nm0000024              John Gielgud      1904      2000
# 26       nm0000027             Alec Guinness      1914      2000
# 30       nm0000031         Katharine Hepburn      1907      2003
# 31       nm0000032           Charlton Heston      1923      2008
# 35       nm0000036             Buster Keaton      1895      1966
# 39       nm0000040           Stanley Kubrick      1928      1999
# 40       nm0000041            Akira Kurosawa      1910      1998
# 44       nm0000045                 Bruce Lee      1940      1973
# 45       nm0000046              Vivien Leigh      1913      1967
# 47       nm0000048               Peter Lorre      1904      1964
# ...

# %%
writers = writers[['nconst', 'primaryName', 'birthYear', 'deathYear', 'knownForTitles']]

# %%
writers = writers[writers['birthYear'].notnull()]

# %%
writers_filtered = writers [(writers.birthYear != '\\N')]

# %%
writers_filtered = writers_filtered [(writers_filtered.knownForTitles != '\\N')]

# %%
writers_filtered = writers_filtered.join(writers_filtered['knownForTitles'].str.split(',', expand=True).rename(columns={0:'Title1', 1:'Title2', 2:'Title3', 3:'Title4'}))

# %%
writers_filtered = writers_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1', 'Title2', 'Title3', 'Title4']]

# %%
W_Title1 = writers_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1']]

# %%
W_Title2 = writers_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title2']];

W_Title3 = writers_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title3']];

W_Title4 = writers_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title4']]

# %%
W_Title1.rename(columns = {'Title1':'Title'}, inplace = True);

W_Title2.rename(columns = {'Title2':'Title'}, inplace = True);

W_Title3.rename(columns = {'Title3':'Title'}, inplace = True);

W_Title4.rename(columns = {'Title4':'Title'}, inplace = True);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
W_Title_edited = pandas.concat([W_Title1, W_Title2, W_Title3, W_Title4], ignore_index=True)

# %%
written_by = W_Title_edited[['nconst', 'Title']]

# %%
written_by
# Out:
#            nconst       Title
# 0       nm0000004   tt0072562
# 1       nm0000005   tt0069467
# 2       nm0000019   tt0050783
# 3       nm0000024   tt0071877
# 4       nm0000027   tt0076759
# 5       nm0000031   tt0043265
# 6       nm0000032   tt0052618
# 7       nm0000036   tt0015324
# 8       nm0000040   tt0120663
# 9       nm0000041   tt0089881
# 10      nm0000045   tt0070034
# 11      nm0000046   tt0044081
# 12      nm0000048   tt0036613
# 13      nm0000050   tt0028772
# 14      nm0000051   tt0084855
# 15      nm0000054   tt0050861
# 16      nm0000064   tt0040506
# 17      nm0000073   tt0030657
# 18      nm0000076   tt0075860
# 19      nm0000080   tt0038991
# 20      nm0000086   tt0079200
# 21      nm0000088   tt0063752
# 22      nm0000090   tt0139809
# 23      nm0000091   tt0152930
# 24      nm0000092   tt0071853
# 25      nm0000095   tt0075686
# 26      nm0000100   tt1634122
# 27      nm0000101   tt0080455
# 28      nm0000104   tt0112851
# 29      nm0000108   tt0119116
# ...

# %%
written_by.to_csv('written_by.csv', index=False)

# %%
actor = actor[['nconst', 'primaryName', 'birthYear', 'deathYear', 'knownForTitles']];

actor = actor[actor['birthYear'].notnull()];

actor_filtered = actor [(actor.birthYear != '\\N')];

actor_filtered = actor_filtered [(actor_filtered.knownForTitles != '\\N')];

actor_filtered.to_csv('actor_filtered_NoNULLBirthYear_NoNULLTitle.csv', index=False);

actor_filtered = actor_filtered.join(actor_filtered['knownForTitles'].str.split(',', expand=True).rename(columns={0:'Title1', 1:'Title2', 2:'Title3', 3:'Title4'}));

actor_filtered = actor_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1', 'Title2', 'Title3', 'Title4']];

actorTitle1 = actor_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1']];

actorTitle2 = actor_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title2']];

actorTitle3 = actor_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title3']];

actorTitle4 = actor_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title4']];

actorTitle1 = actorTitle1[actorTitle1['Title1'].notnull()];

actorTitle2 = actorTitle2[actorTitle2['Title2'].notnull()];

actorTitle3 = actorTitle3[actorTitle3['Title3'].notnull()];

actorTitle4 = actorTitle4[actorTitle4['Title4'].notnull()];

actorTitle1.rename(columns = {'Title1':'Title'}, inplace = True);

actorTitle2.rename(columns = {'Title2':'Title'}, inplace = True);

actorTitle3.rename(columns = {'Title3':'Title'}, inplace = True);

actorTitle4.rename(columns = {'Title4':'Title'}, inplace = True);

actorTitle_edited = pandas.concat([Title1, Title2, Title3, Title4], ignore_index=True);

actor_by = actorTitle_edited[['nconst', 'Title']];

# %%
actor_by.to_csv('actor_by.csv', index=False)

# %%
actor_by
# Out:
#            nconst       Title
# 0       nm0000005   tt0069467
# 1       nm0000008   tt0078788
# 2       nm0000010   tt0031867
# 3       nm0000019   tt0050783
# 4       nm0000024   tt0071877
# 5       nm0000032   tt0052618
# 6       nm0000033   tt0052357
# 7       nm0000036   tt0015324
# 8       nm0000037   tt0041716
# 9       nm0000040   tt0120663
# 10      nm0000041   tt0089881
# 11      nm0000056   tt0084855
# 12      nm0000059   tt0077269
# 13      nm0000071   tt0052561
# 14      nm0000076   tt0075860
# 15      nm0000080   tt0038991
# 16      nm0000087   tt5847740
# 17      nm0000088   tt0063752
# 18      nm0000090   tt0139809
# 19      nm0000091   tt0152930
# 20      nm0000095   tt0075686
# 21      nm0000097   tt0426592
# 22      nm0000099   tt0108399
# 23      nm0000108   tt0119116
# 24      nm0000110   tt0116477
# 25      nm0000111   tt0086567
# 26      nm0000114   tt0105236
# 27      nm0000116   tt0090605
# 28      nm0000123   tt0465538
# 29      nm0000127   tt0111686
# ...

# %%
actress = actress[['nconst', 'primaryName', 'birthYear', 'deathYear', 'knownForTitles']];

actress = actress[actress['birthYear'].notnull()];

actress_filtered = actress [(actress.birthYear != '\\N')];

actress_filtered = actress_filtered [(actress_filtered.knownForTitles != '\\N')];

actress_filtered.to_csv('actress_filtered_NoNULLBirthYear_NoNULLTitle.csv', index=False);

actress_filtered = actress_filtered.join(actress_filtered['knownForTitles'].str.split(',', expand=True).rename(columns={0:'Title1', 1:'Title2', 2:'Title3', 3:'Title4'}));

actress_filtered = actress_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1', 'Title2', 'Title3', 'Title4']];

actressTitle1 = actress_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title1']];

actressTitle2 = actress_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title2']];

actressTitle3 = actress_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title3']];

actressTitle4 = actress_filtered[['nconst', 'primaryName', 'birthYear', 'deathYear', 'Title4']];

actressTitle1 = actressTitle1[actressTitle1['Title1'].notnull()];

actressTitle2 = actressTitle2[actressTitle2['Title2'].notnull()];

actressTitle3 = actressTitle3[actressTitle3['Title3'].notnull()];

actressTitle4 = actressTitle4[actressTitle4['Title4'].notnull()];

actressTitle1.rename(columns = {'Title1':'Title'}, inplace = True);

actressTitle2.rename(columns = {'Title2':'Title'}, inplace = True);

actressTitle3.rename(columns = {'Title3':'Title'}, inplace = True);

actressTitle4.rename(columns = {'Title4':'Title'}, inplace = True);

actressTitle_edited = pandas.concat([Title1, Title2, Title3, Title4], ignore_index=True);

actress_by = actressTitle_edited[['nconst', 'Title']];

# %%
actress_by
# Out:
#            nconst       Title
# 0       nm0000005   tt0069467
# 1       nm0000008   tt0078788
# 2       nm0000010   tt0031867
# 3       nm0000019   tt0050783
# 4       nm0000024   tt0071877
# 5       nm0000032   tt0052618
# 6       nm0000033   tt0052357
# 7       nm0000036   tt0015324
# 8       nm0000037   tt0041716
# 9       nm0000040   tt0120663
# 10      nm0000041   tt0089881
# 11      nm0000056   tt0084855
# 12      nm0000059   tt0077269
# 13      nm0000071   tt0052561
# 14      nm0000076   tt0075860
# 15      nm0000080   tt0038991
# 16      nm0000087   tt5847740
# 17      nm0000088   tt0063752
# 18      nm0000090   tt0139809
# 19      nm0000091   tt0152930
# 20      nm0000095   tt0075686
# 21      nm0000097   tt0426592
# 22      nm0000099   tt0108399
# 23      nm0000108   tt0119116
# 24      nm0000110   tt0116477
# 25      nm0000111   tt0086567
# 26      nm0000114   tt0105236
# 27      nm0000116   tt0090605
# 28      nm0000123   tt0465538
# 29      nm0000127   tt0111686
# ...

# %%
actress_by.to_csv('actress_by.csv', index=False)

# %%
actor
# Out:
#             nconst           primaryName birthYear deathYear  \
# 0        nm0000001          Fred Astaire      1899      1987
# 3        nm0000004          John Belushi      1949      1982
# 4        nm0000005        Ingmar Bergman      1918      2007
# 6        nm0000007       Humphrey Bogart      1899      1957
# 7        nm0000008         Marlon Brando      1924      2004
# 8        nm0000009        Richard Burton      1925      1984
# 9        nm0000010          James Cagney      1899      1986
# 10       nm0000011           Gary Cooper      1901      1961
# 14       nm0000015            James Dean      1931      1955
# 17       nm0000018          Kirk Douglas      1916      2020
# 19       nm0000020           Henry Fonda      1905      1982
# 21       nm0000022           Clark Gable      1901      1960
# 23       nm0000024          John Gielgud      1904      2000
# 25       nm0000026            Cary Grant      1904      1986
# ...

# %%
actress
# Out:
#             nconst           primaryName birthYear deathYear  \
# 0        nm0000001          Fred Astaire      1899      1987
# 3        nm0000004          John Belushi      1949      1982
# 4        nm0000005        Ingmar Bergman      1918      2007
# 6        nm0000007       Humphrey Bogart      1899      1957
# 7        nm0000008         Marlon Brando      1924      2004
# 8        nm0000009        Richard Burton      1925      1984
# 9        nm0000010          James Cagney      1899      1986
# 10       nm0000011           Gary Cooper      1901      1961
# 14       nm0000015            James Dean      1931      1955
# 17       nm0000018          Kirk Douglas      1916      2020
# 19       nm0000020           Henry Fonda      1905      1982
# 21       nm0000022           Clark Gable      1901      1960
# 23       nm0000024          John Gielgud      1904      2000
# 25       nm0000026            Cary Grant      1904      1986
# ...

# %%
df_ratings = pandas.read_csv('./ratings.csv')

# %%
df_ratings
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000009            5.9       193
# 1       tt0000446            6.3        25
# 2       tt0000574            6.1       750
# 3       tt0000591            5.2        16
# 4       tt0000679            5.3        65
# 5       tt0000969            6.7        25
# 6       tt0001105            6.5       890
# 7       tt0001285            5.6        57
# 8       tt0001321            5.3        55
# 9       tt0001381            5.4        37
# 10      tt0001432            5.6        27
# 11      tt0001482            5.1        78
# 12      tt0001498            7.7        12
# 13      tt0001592            5.5        14
# 14      tt0001614            6.1        26
# 15      tt0001692            5.3        14
# 16      tt0001790            6.0        44
# 17      tt0001877            5.3        69
# 18      tt0001892            5.9       227
# 19      tt0001911            4.5        22
# 20      tt0001915            5.7       114
# ...

# %%
written_by = written_by[written_by['Title'].notnull()]

# %%
written_by.to_csv('written_by.csv', index=False)

# %%
written_by_new = written_by[['nconst']]

# %%
written_by_new = written_by_new.drop_duplicates()

# %%
written_by_new.to_csv('writers.csv', index=False)

# %%
actor_by_new = actor_by[['nconst']]

# %%
actor_by_new = actor_by_new.drop_duplicates()

# %%
actor_by_new.to_csv('actors.csv', index=False)

# %%
directed_by_new = directed_by[['nconst']]

# %%
directed_by_new = directed_by_new.drop_duplicates()

# %%
directed_by_new.to_csv('director.csv', index=False)

# %%
df_genres = pandas.read_csv('./genres.csv')

# %%
df_genres
# Out:
#                             genres
# 0                    Romance,Short
# 1                    Short,Western
# 2       Action,Adventure,Biography
# 3                            Drama
# 4                Adventure,Fantasy
# 5              Drama,History,Short
# 6                      Drama,Short
# 7           Biography,Drama,Family
# 8                  Drama,Short,War
# 9                              War
# 10            Fantasy,Sci-Fi,Short
# 11         Biography,Drama,History
# 12                           Short
# 13             Drama,Romance,Short
# 14                       Short,War
# 15                   Drama,History
# 16         Adventure,Drama,Fantasy
# 17                 Biography,Drama
# 18         Biography,Drama,Romance
# 19                     Documentary
# 20                     History,War
# 21             Drama,Short,Western
# 22         Adventure,Drama,Romance
# 23              Drama,Horror,Short
# 24               Crime,Drama,Short
# 25            Drama,Short,Thriller
# ...

# %%
df_genreOf = pandas.read_csv('./genreOf.csv')

# %%
df_genreOf = df_genreOf.join(df_genreOf['genres'].str.split(',', expand=True).rename(columns={0:'Title1', 1:'Title2', 2:'Title3'}))

# %%
df_genreOf = df_genreOf[['tconst', 'Title1', 'Title2', 'Title3']]

# %%
df_genreOf1 = df_genreOf[['tconst', 'Title1']];

df_genreOf2 = df_genreOf[['tconst', 'Title2']];

df_genreOf3 = df_genreOf[['tconst', 'Title3']];

df_genreOf1 = df_genreOf1[df_genreOf1['Title1'].notnull()];

df_genreOf2 = df_genreOf2[df_genreOf2['Title2'].notnull()];

df_genreOf3 = df_genreOf3[df_genreOf3['Title3'].notnull()];

df_genreOf1.rename(columns = {'Title1':'Title'}, inplace = True);

df_genreOf2.rename(columns = {'Title2':'Title'}, inplace = True);

df_genreOf3.rename(columns = {'Title3':'Title'}, inplace = True);

df_genreOf_edited = pandas.concat([df_genreOf1, df_genreOf2, df_genreOf3], ignore_index=True);

# %%
df_genreOf_edited.drop_duplicates()
# Out:
#            tconst      Title
# 0       tt0000009    Romance
# 1       tt0000446      Short
# 2       tt0000574     Action
# 3       tt0000591      Drama
# 4       tt0000679  Adventure
# 5       tt0000969      Drama
# 6       tt0001105      Drama
# 7       tt0001285  Biography
# 8       tt0001321      Short
# 9       tt0001381      Drama
# 10      tt0001432      Drama
# 11      tt0001482      Drama
# 12      tt0001498        War
# 13      tt0001592      Drama
# 14      tt0001614      Drama
# 15      tt0001692      Drama
# 16      tt0001790      Drama
# 17      tt0001877    Fantasy
# 18      tt0001892      Drama
# 19      tt0001911  Biography
# 20      tt0001915      Drama
# 21      tt0001963      Drama
# 22      tt0001964      Drama
# 23      tt0002029      Short
# 24      tt0002057      Drama
# 25      tt0002078      Drama
# 26      tt0002083      Short
# 27      tt0002101      Drama
# 28      tt0002122      Drama
# 29      tt0002126     Action
# ...           ...        ...
# ...

# %%
df_genreOf_edited.to_csv('genreOf.csv', index=False)

# %%
df_genres = df_genreOf_edited[['Title']]

# %%
df_genres_edited = df_genres.drop_duplicates()

# %%
df_genres_edited.to_csv('genres.csv', index=False)

# %%
df_genreOf_edited.rename(columns = {'Title':'Genre'}, inplace = True);

# %%
df_genreOf_edited.to_csv('genreOf.csv', index=False);

# %%
df_genres_edited.rename(columns = {'Title':'Genre'}, inplace = True);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_genres_edited.to_csv('genres.csv', index=False)

# %%
df_genres_edited
# Out:
#              Genre
# 0          Romance
# 1            Short
# 2           Action
# 3            Drama
# 4        Adventure
# 7        Biography
# 12             War
# 17         Fantasy
# 41     Documentary
# 44         History
# 52           Crime
# 59          Comedy
# 60          Horror
# 89         Mystery
# 121        Western
# 144             \N
# 1439        Family
# 1788         Music
# 2800     Animation
# 3734        Sci-Fi
# 4024         Sport
# 5734      Thriller
# 6484       Musical
# 14714    Film-Noir
# 17840    Talk-Show
# 17857    Game-Show
# 19622         News
# 29898        Adult
# 33354   Reality-TV

# %%
df_person = pandas.read_csv('./name.basics.csv')

# %%
df_person.head(10)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# 8            actor,soundtrack,producer
# ...

# %%
df_person = df_person[df_person['birthYear'].notnull()];

df_person = df_person [(df_person.birthYear != '\\N')];

# %%
df_person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221542 entries, 0 to 1106607
# Data columns (total 6 columns):
# nconst               221542 non-null object
# primaryName          221542 non-null object
# birthYear            221542 non-null object
# deathYear            221542 non-null object
# primaryProfession    213169 non-null object
# knownForTitles       221542 non-null object
# dtypes: object(6)
# memory usage: 11.8+ MB

# %%
df_person = df_person[df_person['knownForTitles'].notnull()];

df_person = df_person [(df_person.knownForTitles != '\\N')];

# %%
df_person.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220816 entries, 0 to 1106607
# Data columns (total 6 columns):
# nconst               220816 non-null object
# primaryName          220816 non-null object
# birthYear            220816 non-null object
# deathYear            220816 non-null object
# primaryProfession    212910 non-null object
# knownForTitles       220816 non-null object
# dtypes: object(6)
# memory usage: 11.8+ MB

# %%
df_person.to_csv('persons.csv', index=False)
