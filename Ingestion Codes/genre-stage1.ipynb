# %%
import pandas

# %%
df_movies = pandas.read_csv('./movies.csv')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47992 entries, 0 to 47991
# Data columns (total 6 columns):
# tconst            47992 non-null object
# primaryTitle      47992 non-null object
# isAdult           47992 non-null int64
# startYear         47992 non-null int64
# runtimeMinutes    47992 non-null int64
# genres            47992 non-null object
# dtypes: int64(3), object(3)
# memory usage: 2.2+ MB

# %%
genreOf = df_movies [['tconst', 'genres']]

# %%
genreOf
# Out:
#           tconst                      genres
# 0      tt0069049                       Drama
# 1      tt0100275        Comedy,Drama,Fantasy
# 2      tt0116991                       Drama
# 3      tt0137204  Adventure,Animation,Comedy
# 4      tt0137818                          \N
# 5      tt0176694     Animation,Drama,History
# 6      tt0191476                      Comedy
# 7      tt0192528                       Drama
# 8      tt0230212                       Drama
# 9      tt0249516  Action,Adventure,Animation
# 10     tt0276568                Action,Drama
# 11     tt0285252                      Comedy
# 12     tt0293069                    Thriller
# 13     tt0306058                          \N
# 14     tt0311448               Drama,Romance
# 15     tt0315642          Action,Crime,Drama
# 16     tt0323808                Drama,Horror
# 17     tt0326592                          \N
# 18     tt0326965      Drama,Mystery,Thriller
# 19     tt0329539     Adventure,Comedy,Family
# ...
